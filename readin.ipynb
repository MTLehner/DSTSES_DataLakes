# %%
import json
import numpy as np

# %%
import os
files = os.listdir('./data/lakegreifenctdprofiles_datalakesdownload/')

# %%
files = [file for file in files if '.json' in file]

# %%
np.float32

# %%
zs = []
xs = []
for file in np.sort(files):
    with open('./data/lakegreifenctdprofiles_datalakesdownload/%s' % file) as f:
        data = json.load(f)        
        zs += list(np.nanmean(np.array(data['z6'][:10],dtype=np.float32),axis=0))
        xs += data['x'][0]
# Out:
# /var/folders/_5/3hgthxvn7tl3x0x0997zcpq00000gn/T/ipykernel_58473/3611023620.py:6: RuntimeWarning: Mean of empty slice
#   zs += list(np.nanmean(np.array(data['z6'][:10],dtype=np.float32),axis=0))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 7
#       5 data = json.load(f)
#       6 zs += list(np.nanmean(np.array(data['z6'][:10],dtype=np.float32),axis=0))
# ----> 7 xs += data['x'][0]
#
# TypeError: 'float' object is not iterable

# %%
x
# Out:
# [1682294942.1,
#  1682316541.5,
#  1682338139.7,
#  1682359739.5,
#  1682381342.9,
#  1682402937.6,
#  1682424540.6,
#  1682446136.7,
#  1682467734.8,
#  1682489336.9,
#  1682510938.4,
#  1682532541.4,
#  1682554141]

# %%
plt.plot(zs)

# %%
np.array(data['z6'][:10])
# Out:
# array([[None, 10.4, 9.1, 8.7, 17.6, 15.6, 12.9, 13.2, 10.4, 9.3, 13.1,
#         16.5, 19.4, 20.5, 18.8, 17, 15.4, 14.1, 14.5, 17.8, 22.2, 18.7,
#         18.2, 16.4, 14.7, 12.9, 13.7, 12.5, 17, 18.2, 17.6, 17.6, 10.7,
#         9, 9.9, 11.8, 13.6],
#        [None, 9.1, 8.5, 9.3, 19, 16.6, 15, 19, 11.2, 11.2, 13.2, 16.5,
#         19.5, 22.2, 18.5, 16.2, 15.7, 14.5, 14.7, 17.8, 20.6, 22.7, 19.4,
#         19.1, 13.7, 12.5, 15.3, 14.8, 16.9, 19.4, 19.1, 17.6, 13.3, 10.3,
#         10.4, 11.1, 17.1],
#        [None, 13.6, 10, 9.4, 15.6, 15.9, 13.7, 14.9, 10, 11.9, 12.6,
#         15.9, 20.9, 18.8, 21.7, 19.9, 13.9, 14.3, 14.4, 18.7, 21.3, 20.7,
#         21.1, 18.9, 18.6, 18.4, 11, 15.4, 15.8, 18.8, 21.5, 14.6, 12.1,
#         8.7, 9.6, 12.6, 14.2],
#        [None, 9.7, 11, 10.5, 13.5, 14.6, 16.4, 12.9, 10.4, 12.4, 14.2,
#         15.4, 17.3, 19.9, 15.4, 15.1, 13.9, 15.4, 16.1, 23.6, 20.7, 20.8,
#         18.9, 17.5, 15.2, 19.1, 12, 12.4, 17.7, 23.1, 17.8, 16.7, 12,
# ...

# %%
data.keys()
# Out:
# dict_keys(['x', 'y', 'z', 'z1', 'z2', 'z3', 'z4', 'z5', 'z6', 'z7', 'z8', 'z9'])

# %%
import numpy as np
np.nanmean(np.array(data['z6'][:10])[:,1:],axis=0)
# Out:
# array([10.749999999999998, 10.06, 9.93, 15.529999999999998,
#        15.760000000000002, 14.700000000000003, 13.87, 10.59,
#        11.319999999999997, 13.98, 17.09, 19.490000000000002,
#        20.520000000000003, 18.779999999999998, 18.14, 15.05,
#        15.100000000000003, 16.169999999999998, 18.59, 20.9,
#        21.450000000000003, 19.439999999999998, 17.43, 14.709999999999999,
#        14.98, 12.55, 13.7, 18.01, 19.419999999999998, 18.38, 16.46, 12.11,
#        9.069999999999999, 10.37, 11.91, 15.680000000000001], dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
len(data['z'])
# Out:
# 161

# %%
_ = plt.scatter(data['z'][0],data['z6'][0])
